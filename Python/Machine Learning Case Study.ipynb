# %%
# importing liabraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %%
# reading the csv
df = pd.read_csv(r"D:\SDBI\4th Semester\Mashine Learning\Datasets\Dataset.csv")

# %%
# veiwing the data

display(df.head(),df.tail(),df.sample(5))
# Out:
#    Room Area (sq. ft.)  Number of Appliances  Outside Temperature (C)  \
# 0                  270                    15                       30
# 1                  273                    20                       28
# 2                  276                    18                       26
# 3                  276                    12                       32
# 4                  276                    22                       20
#
#    Insulation Thickness (inches) Building Type  HVAC System  \
# 0                            2.0   Residential   Central AC
# 1                            1.5    Commercial     Split AC
# 2                            1.8   Residential    Window AC
# 3                            2.5   Residential   Central AC
# 4                            1.2    Commercial     Split AC
#
#    Average Temperature in last 24 hours (C)  Energy Consumption (kWh)
# 0                                        28                       380
# ...

# %%
# checking dataset's info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 8 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Room Area (sq. ft.)                       45 non-null     int64
#  1   Number of Appliances                      45 non-null     int64
#  2   Outside Temperature (C)                   45 non-null     int64
#  3   Insulation Thickness (inches)             45 non-null     float64
#  4   Building Type                             45 non-null     object
#  5   HVAC System                               45 non-null     object
#  6   Average Temperature in last 24 hours (C)  45 non-null     int64
#  7   Energy Consumption (kWh)                  45 non-null     int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 2.9+ KB

# %%
# checking the central tendencies
df.describe()
# Out:
#        Room Area (sq. ft.)  Number of Appliances  Outside Temperature (C)  \
# count            45.000000             45.000000                45.000000
# mean            274.822222             17.577778                23.044444
# std               1.556349              3.026316                 6.201010
# min             270.000000             12.000000                10.000000
# 25%             274.000000             16.000000                18.000000
# 50%             275.000000             18.000000                23.000000
# 75%             276.000000             20.000000                28.000000
# max             277.000000             23.000000                33.000000
#
#        Insulation Thickness (inches)  \
# count                      45.000000
# mean                        1.782222
# std                         0.376158
# min                         1.100000
# 25%                         1.500000
# 50%                         1.800000
# ...

# %%
# checking the correlation
df.corr()
# Out:
#                                           Room Area (sq. ft.)  \
# Room Area (sq. ft.)                                  1.000000
# Number of Appliances                                 0.056081
# Outside Temperature (C)                              0.026742
# Insulation Thickness (inches)                       -0.055989
# Average Temperature in last 24 hours (C)             0.032260
# Energy Consumption (kWh)                             0.039561
#
#                                           Number of Appliances  \
# Room Area (sq. ft.)                                   0.056081
# Number of Appliances                                  1.000000
# Outside Temperature (C)                              -0.514895
# Insulation Thickness (inches)                        -0.981021
# Average Temperature in last 24 hours (C)             -0.517361
# Energy Consumption (kWh)                              0.956444
#
#                                           Outside Temperature (C)  \
# ...

# %%
sns.heatmap(df.corr(),annot= True)
plt.plot();

# %%
sns.pairplot(df,diag_kind = 'kde')

# %%
df.hist()
plt.tight_layout()

# %% [markdown]
# **Inference:**
# - Room Area field's data is majorly on right side its safe to assume that it is **left skewed**.
# - Number of Appliances's data it is really close to **normal distribution** but it can also be **multimodal distribution**.
# - Outside temperature's data looks like its close to normal distribution.
# -
